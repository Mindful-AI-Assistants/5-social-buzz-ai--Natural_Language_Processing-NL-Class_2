# %% [markdown]
# # 📓 Notebook: Pipeline e Pré-processamento em PLN (Aula 1)
#
# ## 1\. Introdução ao Processamento de Linguagem Natural (PLN)
#
# O Processamento de Linguagem Natural (PLN), ou Natural Language Processing (NLP), é um campo de estudo fundamental na intersecção entre a ciência da computação, a inteligência artificial e a linguística. Seu foco é fazer com que os computadores processem, "entendam" e alavanquem dados de linguagem humana.
#
# O estudo do PLN é motivado pelo imenso volume de dados de linguagem gerados diariamente, sendo a maior parte deles textuais. O ponto central da computação é auxiliar os seres humanos; portanto, o PLN é um passo obrigatório para que os computadores auxiliem significativamente nossas vidas, entendendo a forma como nos comunicamos.
#
# Os dois pilares do PLN são:
#
#   * **Representação:** Focada em converter o significado simbólico da linguagem (palavras, fala, sinais) em uma forma que o computador possa entender, geralmente dados numéricos, como vetores densos (embeddings).
#   * **Modelagem:** Envolve o uso dessas representações numéricas para executar tarefas de linguagem, o que hoje é dominado por Redes Neurais Profundas.
#
# ## 2\. Configuração do Ambiente e Pipeline Genérica
#
# Antes de iniciar qualquer tarefa de PLN, definimos a pipeline genérica, que é conceitualmente dividida em fases distintas:
#
# 1.  Aquisição de Dados
# 2.  Limpeza (Text Cleaning)
# 3.  Pré-processamento
# 4.  Feature Engineering (Representação de Texto)
# 5.  Modelagem
# 6.  Avaliação
#
# Neste Notebook, focaremos nas etapas 2 e 3: **Limpeza** e **Pré-processamento**.

# %%
# !pip install nltk
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 444.4 kB/s eta 0:00:00a 0:00:01
# ...

# %%
import re
import nltk # Usado para muitas tarefas de PLN, como tokenização e stemming
from nltk.corpus import stopwords
# No ambiente real, usaríamos ferramentas como Spark NLP para pipelines complexas

# Importações comuns para tarefas de pré-processamento

# Simulação de dados de texto que geralmente é o ponto de partida
texto_bruto = """
<doc>
  <title>AULA 1 - Exemplo de PLN</title>
  <text>
    O PLN é uma Ã¡rea crÃtica! HÃ¡ muitos dados textuais (e.g., TwEETS, comentÃ¡rios).
    A tokenizaÃ§Ã£o (tokenizer) Ã© a primeira etapa. NÃ£o se esqueÃ§a de LematizaÃ§Ã£o.
    É FÁCIL SOBREAJUSTAR O MODELO (overfitting).
  </text>
</doc>
"""



# ----------------------------------------------------
# 1. Etapa de Aquisição de Dados
# Em projetos reais, envolve a coleta de datasets públicos ou rotulados.
# Aqui, usamos uma string de exemplo que simula dados "sujos" extraídos (scraped data).
print("Texto Bruto Adquirido:\n", texto_bruto)
# Out:
# Texto Bruto Adquirido:
#
# <doc>
#   <title>AULA 1 - Exemplo de PLN</title>
#   <text>
#     O PLN é uma Ã¡rea crÃtica! HÃ¡ muitos dados textuais (e.g., TwEETS, comentÃ¡rios).
#     A tokenizaÃ§Ã£o (tokenizer) Ã© a primeira etapa. NÃ£o se esqueÃ§a de LematizaÃ§Ã£o.
#     É FÁCIL SOBREAJUSTAR O MODELO (overfitting).
#   </text>
# </doc>

# %% [markdown]
# ## 3\. Etapa de Limpeza de Texto (Text Cleaning)
#
# A Limpeza de Texto é crítica, pois afeta todas as fases subsequentes da pipeline. O foco é a extração do texto bruto e a remoção de informações não textuais.
#
# Exemplos de tarefas de limpeza incluem:
#
#   * Remoção de marcações HTML/XML, metadados e artefatos de raspagem.
#   * Normalização de Unicode e correção ortográfica (crucial para dados de mídias sociais).
#
# <!-- end list -->

# %%
# 2. Etapa de Limpeza (Text Cleaning)

# 2.1 Remoção de Marcações e Metadados
# Remove tags XML/HTML.
texto_limpo = re.sub(r'<[^>]+>', '', texto_bruto)
texto_limpo = texto_limpo.strip()

# 2.2 Normalização de Unicode (Exemplo simples: substituição de acentos codificados incorretamente)
# No exemplo, corrigimos codificações erradas comuns (Ã¡ -> á, Ã§ -> ç)
texto_normalizado = texto_limpo.replace("Ã¡", "á").replace("Ã£", "ã").replace("Ã©", "é").replace("Ã§", "ç").replace("Ã", "í")

print("Texto após Limpeza e Normalização de Unicode:\n", texto_normalizado)
# Out:
# Texto após Limpeza e Normalização de Unicode:
#  AULA 1 - Exemplo de PLN
#
#     O PLN é uma área crítica! Há muitos dados textuais (e.g., TwEETS, comentários).
#     A tokenização (tokenizer) é a primeira etapa. Não se esqueça de Lematização.
#     É FÁCIL SOBREAJUSTAR O MODELO (overfitting).

# %% [markdown]
# ## 4\. Etapa de Pré-processamento: Tokenização e Segmentação
#
# Após a limpeza, o Pré-processamento converte o texto em uma forma canônica e estruturalmente utilizável, pois o software de PLN opera no nível de sentença e palavra.
#
# ### 4.1 Tokenização
#
# A Tokenização é uma das técnicas mais fundamentais e a primeira etapa crucial do pré-processamento. Consiste em dividir uma string de caracteres em pedaços menores, geralmente palavras, chamadas **tokens**. O PLN geralmente opera no nível de palavra, pois é a menor unidade de significado conveniente.
#
# Embora em inglês um tokenizer simples possa usar espaços em branco, o processo é afetado pelo sistema de escrita da linguagem e deve lidar com complexidades como pontuações e abreviações (e.g., dividindo "NLP." em "NLP" e ".").

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/rooneycoelho/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# 3. Etapa de Pré-processamento

# A Segmentação de Sentença (Sentence Segmentation) é um preliminar essencial.
# Usamos o NLTK para simular o processo.

# Download dos recursos necessários do NLTK (para tokenização)
# nltk.download('punkt')

from nltk.tokenize import sent_tokenize
# Nota: Para este exemplo, simplificaremos, mas sent_tokenize() realiza a separação de frases.

# Tokenização de Palavras (Word Tokenization)
from nltk.tokenize import word_tokenize

# Tratamento do texto para Tokenização (remoção de quebras de linha/espaços excessivos)
texto_para_tokenizar = re.sub(r'\s+', ' ', texto_normalizado)
tokens = word_tokenize(texto_para_tokenizar)

print(f"Número total de tokens: {len(tokens)}")
print("\nTokens (unidades atômicas de significado):\n", tokens)
# Out:
# Número total de tokens: 50
#
# Tokens (unidades atômicas de significado):
#  ['AULA', '1', '-', 'Exemplo', 'de', 'PLN', 'O', 'PLN', 'é', 'uma', 'área', 'crítica', '!', 'Há', 'muitos', 'dados', 'textuais', '(', 'e.g.', ',', 'TwEETS', ',', 'comentários', ')', '.', 'A', 'tokenização', '(', 'tokenizer', ')', 'é', 'a', 'primeira', 'etapa', '.', 'Não', 'se', 'esqueça', 'de', 'Lematização', '.', 'É', 'FÁCIL', 'SOBREAJUSTAR', 'O', 'MODELO', '(', 'overfitting', ')', '.']

# %% [markdown]
# ## 5\. Etapa de Pré-processamento: Redução de Vocabulário e Normalização
#
# O Pré-processamento também inclui a **Redução de Vocabulário**, visando agrupar formas flexionadas da mesma palavra em uma única forma canônica, além de outras práticas de normalização.
#
# ### 5.1 Redução de Vocabulário: Stemming e Lematização
#
# Reduzir o vocabulário é essencial para evitar que o modelo trate variações de uma mesma palavra (como "estudar", "estudando", "estudante") como entidades distintas, o que pode levar ao sobreajuste (overfitting).
#
# | Técnica | Objetivo |
# | :--- | :--- |
# | **Stemming** | Remove afixos gramaticais (sufixos/prefixos), frequentemente resultando em uma "raiz" que pode não ser uma palavra real (e.g., *organi* de organização). |
# | **Lematização** | Reduz a palavra à sua forma de dicionário (lema), que é uma palavra válida (e.g., *organização* para organização ou *correr* para correndo). |
#
# Geralmente, a lematização é mais sofisticada, pois utiliza informações de contexto (POS tagging) para garantir que a palavra base seja morfologicamente correta.

# %%
nltk.download('rslp')
# Out:
# [nltk_data] Downloading package rslp to
# [nltk_data]     /Users/rooneycoelho/nltk_data...
# [nltk_data]   Unzipping stemmers/rslp.zip.
# True

# %%
# !pip install spacy

# %%
# !python -m spacy download pt_core_news_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 1.7 MB/s eta 0:00:0000:0100:01m
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')

# %%
import spacy

nlp = spacy.load("pt_core_news_sm")

# %%
# Simulação de Redução de Vocabulário usando NLTK (para fins didáticos)

# Exemplo de Lowercasing (Conversão para minúsculas)
# Converter todo o texto para minúsculas é uma boa prática de normalização,
# pois em muitos casos, o caso não é relevante para o problema (e.g., classificação de notícias).
tokens_lower = [t.lower() for t in tokens]
print("Tokens em minúsculas (Lowercasing):\n", tokens_lower)

# Exemplo de Stemming (usando RSLP Stemmer para Português, se disponível, ou uma simulação)
# Como nossos tokens estão em Português e o ambiente PySpark/SparkNLP é frequentemente preferido,
# usamos a implementação de conceitos.
# Exemplo teórico de Stemming:
# from nltk.stem import PorterStemmer # Para Inglês
# stemmer = PorterStemmer()
# stems = [stemmer.stem(t) for t in tokens_lower]
# print("\nExemplo de Stems (inglês, apenas demonstração):", stems)

lemma = [t.lemma_ for t in nlp(" ".join(tokens_lower))]
print("\nLemas (Português):\n", lemma)

stemmer = nltk.stem.RSLPStemmer()
stems = [stemmer.stem(t) for t in tokens_lower]
print("\nTokens após Stemming (Português):\n", stems)

# Exemplo de Lematização (conceitual)
# LemmatizationModel.pretrained() é frequentemente usado em bibliotecas profissionais (e.g., Spark NLP).
print("\nNota: Lematização seria aplicada aqui para obter a forma de dicionário (lema).")
# Out:
# Tokens em minúsculas (Lowercasing):
#  ['aula', '1', '-', 'exemplo', 'de', 'pln', 'o', 'pln', 'é', 'uma', 'área', 'crítica', '!', 'há', 'muitos', 'dados', 'textuais', '(', 'e.g.', ',', 'tweets', ',', 'comentários', ')', '.', 'a', 'tokenização', '(', 'tokenizer', ')', 'é', 'a', 'primeira', 'etapa', '.', 'não', 'se', 'esqueça', 'de', 'lematização', '.', 'é', 'fácil', 'sobreajustar', 'o', 'modelo', '(', 'overfitting', ')', '.']
#
# Lemas (Português):
#  ['aular', '1', '-', 'exemplo', 'de', 'pln', 'o', 'pln', 'ser', 'um', 'área', 'crítico', '!', 'haver', 'muito', 'dado', 'textual', '(', 'e.g.', ',', 'tweet', ',', 'comentário', ')', '.', 'o', 'tokenização', '(', 'tokenizer', ')', 'ser', 'o', 'primeiro', 'etapa', '.', 'não', 'se', 'esquecer', 'de', 'lematização', '.', 'ser', 'fácil', 'sobreajustar', 'o', 'modelo', '(', 'overfitting', ')', '.']
#
# Tokens após Stemming (Português):
# ...

# %% [markdown]
# ### 5.2 Normalização Adicional: Stop Words
#
# Outra prática essencial de normalização é a **Remoção de Stop Words**, que são palavras muito frequentes que não carregam significado de conteúdo útil para o problema (e.g., "a", "an", "o", "de", "em").

# %%
# Definição de Stop Words (exemplo simulado)

# (Em um Colab real, você precisaria baixar o corpus de stopwords)
# nltk.download('stopwords')

stop_words_list = ['a', 'o', 'é', 'e', 'de', 'do', 'da', 'uma', 'um'] # Exemplo simples

# Remoção de Stop Words
# Usamos .isalnum() para remover também pontuações que foram tokenizadas (como '!' e '.')
tokens_filtrados = [word for word in tokens_lower if word not in stop_words_list and word.isalnum()]

print("Tokens após remoção de Stop Words:\n", tokens_filtrados)

# Demonstração de Corpus de Stop Words em Inglês, frequentemente usado em PLN:
# stop_words_en = stopwords.words('english')
# print(f"\nNúmero de Stop Words em Inglês (NLTK): {len(stop_words_en)}")
# Out:
# Tokens após remoção de Stop Words:
#  ['aula', '1', 'exemplo', 'pln', 'pln', 'área', 'crítica', 'há', 'muitos', 'dados', 'textuais', 'tweets', 'comentários', 'tokenização', 'tokenizer', 'primeira', 'etapa', 'não', 'se', 'esqueça', 'lematização', 'fácil', 'sobreajustar', 'modelo', 'overfitting']

# %% [markdown]
# ## 7\. Conclusão
#
# O pipeline de pré-processamento (Limpeza, Tokenização, Normalização e Redução de Vocabulário) é essencial para preparar o texto para a modelagem. Uma vez que o texto é transformado em vetores (Representações Discretas como BoW ou TF-IDF), podemos alimentar algoritmos clássicos de Machine Learning, como o Classificador Naive Bayes, que é frequentemente usado como modelo baseline (linha de base) em classificação de texto devido à sua rapidez e robustez.
#
# O Naive Bayes, contudo, baseia-se na suposição ingênua de que todas as palavras no documento são mutuamente independentes e que a ordem das palavras não importa, o que é uma limitação crucial. Isso motiva a próxima aula a explorar representações mais densas e ricas em contexto, como os Word Embeddings (Word2vec, GloVe), que capturam melhor o significado semântico.
